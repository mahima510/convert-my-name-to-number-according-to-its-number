# %%
#ans 3
import matplotlib.pyplot as p
import numpy as n
x = [-2.5, -1.5, -0.5, 0.5, 1.5, 2.5]
y = [13, 2, 8, 9, 13, 2]

p.stem(x, y)
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:6: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# <StemContainer object of 3 artists>

# %%
x = n.array([19, 21, 18, 2, 8, 9])
N = (len(x)-1)/2 
n = n.array([i for i in n.arange(-N, N+1)]) 
len(x),N,n
# Out:
# (6, 2.5, array([-2.5, -1.5, -0.5,  0.5,  1.5,  2.5]))

# %%
L = []         
l = []
tim = [i for i in n.linspace(-N, N, 1000)] 
n = n.arange(-N, N+1)
for i in n:   
    for t in tim:
        term = 1
        for k in np.arange(-N, N+1):
            if k!=i:
                term = term*((t-k)/(i-k))   
        l.append(term)        
    L.append(l)     
    l=[]

    
for i in range(len(L)):
    p.plot(tim, L[i])
    p.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-9d4fa820294f> in <module>
#       1 L = []
#       2 l = []
# ----> 3 tim = [i for i in n.linspace(-N, N, 1000)]
#       4 n = n.arange(-N, N+1)
#       5 for i in n:
#
# AttributeError: 'numpy.ndarray' object has no attribute 'linspace'

# %%
#ans1
import matplotlib.pyplot as p
import numpy as np

w1 = [5* np.sin(2*np.pi*19*t) for t in np.linspace(0,1,1000)]
w2 = [5* np.cos(2*np.pi*6*t) for t in np.linspace(0,1,1000)]
w3 = [5* np.sin(2*np.pi*2000*t) for t in np.linspace(0,1,1000)]
sig=[]

for i,j,k in zip(w1,w2,w3):
    sig.append(i+j+k)
    

gt = np.fft.fft(sig)
p.plot(gt)
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
#ans4
import thinkdsp as t
import thinkplot as d
from IPython.display import Audio

sample = t.read_wave('noise.wav')
sample = t.play_wave('noise.wav')
sample
spectrum = sample.make_spectrum()
spectrum.plot()
d.show()
noise = spectrum.low_pass(cutoff = 200)
spectrum.plot()
d.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-f5b81ff37a2d> in <module>
#       1 #ans4
# ----> 2 import thinkdsp as t
#       3 import thinkplot as d
#       4 from IPython.display import Audio
#       5
#
# ModuleNotFoundError: No module named 'thinkdsp'
